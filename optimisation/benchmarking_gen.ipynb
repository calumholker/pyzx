# %% [markdown]
# # Benchmarking

# %%
import sys
import time
# sys.path.append('/Users/calum/Developer/pyzx-heuristics-master')
# import pyzx as zx_heuristics
sys.path.append('..')
import pyzx as zx
from benchmarking import benchmark

# %%
# %%script false --no-raise-error
b = benchmark(dirpath='benchmark_gen')
b.show_attributes()
# Out:
# Circuit attributes:  ['Qubits', 'Gates', '2Q Count', 'T Count', 't_simp', 't_opt']
# Loaded functions:  ['cFlow', 'gFlow', 'Heur']
# Loaded routines:  []
# Loaded circuit groups:  ['generated']
#           Original Heur cFlow gFlow
# generated        Y    Y     Y     Y

# %%
# %%script false --no-raise-error
# b = benchmark()
# b.load_circuits('generated_circuits', group_name='generated')

# %%
base_params = [1,1,1,0,0,0,0,0,0]
cFlow_params = [0.37,0.4,0.23,-0.94,-0.71,0.5,-0.45,0.47,0.59]

def cFlow_reduce(c):
    t0 = time.time()
    g = c.to_graph()
    zx.simplify.to_gh(g)
    g2 = zx.simplify.flow_reduce(g,x=base_params, quiet=True)
    t1 = time.time()
    c2 = zx.extract.extract_simple(g2, up_to_perm=True).to_basic_gates()
    c3 = zx.optimize.basic_optimization(c2.copy(), do_swaps=False).to_basic_gates()
    c4 = zx.optimize.basic_optimization(c2.copy(), do_swaps=True).to_basic_gates()
    t2 = time.time()
    if c4.twoqubitcount() < c3.twoqubitcount(): return c4, t1-t0, t2-t0
    return c3, t1-t0, t2-t0

def gFlow_reduce(c):
    t0 = time.time()
    g = c.to_graph()
    zx.simplify.to_gh(g)
    g2 = zx.simplify.flow_reduce(g,x=base_params, flow = 'g', quiet=True)
    t1 = time.time()
    c2 = zx.extract.extract_circuit(g2, up_to_perm=True).to_basic_gates()
    c3 = zx.optimize.basic_optimization(c2.copy(), do_swaps=False).to_basic_gates()
    c4 = zx.optimize.basic_optimization(c2.copy(), do_swaps=True).to_basic_gates()
    t2 = time.time()
    if c4.twoqubitcount() < c3.twoqubitcount(): return c4, t1-t0, t2-t0
    return c3, t1-t0, t2-t0

def zx_heur(c):
    t0 = time.time()
    g = c.to_graph()
    g = zx_heuristics.simplify.teleport_reduce(g)
    g.track_phases = False
    zx_heuristics.simplify.greedy_simp_neighbors(g)
    t1 = time.time()
    c2 = zx_heuristics.extract_circuit(g, up_to_perm=True).to_basic_gates()
    c3 = zx_heuristics.optimize.basic_optimization(c2.copy(), do_swaps=False).to_basic_gates()
    c4 = zx_heuristics.optimize.basic_optimization(c2.copy(), do_swaps=True).to_basic_gates()
    t2 = time.time()
    if c4.twoqubitcount() < c3.twoqubitcount(): return c4, t1-t0, t2-t0
    return c3, t1-t0, t2-t0

def basic(c):
    c1 = zx.optimize.basic_optimization(c.copy(), do_swaps=False).to_basic_gates()
    c2 = zx.optimize.basic_optimization(c.copy(), do_swaps=True).to_basic_gates()
    if c2.twoqubitcount() < c1.twoqubitcount(): return c2
    return c1

# %%
# b.add_simplification_func(zx_heur, 'Heur', groups_to_run=['generated'],verify=False)
# b.add_simplification_func(cFlow_reduce, 'cFlow', groups_to_run=['generated'],verify=False)
# b.add_simplification_func(gFlow_reduce, 'gFlow', groups_to_run=['generated'],verify=False)
b.add_simplification_func(basic, 'Basic', groups_to_run=['generated'],verify=False)
# Out:
# Processing Basic on c_17                                              : 100%|██████████| 20/20 [00:00<00:00, 136.69it/s]

# %%
b.show_attributes()
# Out:
# Circuit attributes:  ['Qubits', 'Gates', '2Q Count', 'T Count', 't_simp', 't_opt']
# Loaded functions:  ['cFlow', 'gFlow', 'Heur', 'Basic']
# Loaded routines:  []
# Loaded circuit groups:  ['generated']
#           Original Basic Heur cFlow gFlow
# generated        Y     Y    Y     Y     Y

# %%
df = b.df(groups=['generated'],
     routines='all',
     funcs='all',
     atts=['Qubits', '2Q Count', 'T Count', 't_simp', 't_opt'])
# Out:
# <style type="text/css">
# #T_eabb7 th.col_heading.level1 {
#   text-align: center;
# }
# #T_eabb7 tr:hover {
#   background-color: #e1f7d5;
#   color: black;
#   font-weight: bold;
# }
# #T_eabb7 .index_name {
#   background-color: #232b2b;
#   font-style: italic;
#   color: white;
#   font-weight: bold;
# }
# #T_eabb7 th:not(.index_name) {
#   background-color: #232b2b;
#   color: white;
# }
# #T_eabb7 th.col_heading.level0 {
#   text-align: center;
#   font-size: 1.2em;
#   padding: 0.7em;
# }
# #T_eabb7 td {
#   text-align: center;
#   font-size: 1em;
# }
# #T_eabb7 th.col0 {
#   border-left: 1px solid white !important;
# }
# #T_eabb7 td.col0 {
#   border-left: 1px solid white !important;
# }
# #T_eabb7 th.col1 {
#   border-left: 1px solid white !important;
# }
# #T_eabb7 td.col1 {
#   border-left: 1px solid white !important;
# }
# #T_eabb7 th.col3 {
#   border-left: 1px solid white !important;
# }
# #T_eabb7 td.col3 {
#   border-left: 1px solid white !important;
# }
# #T_eabb7 th.col5 {
#   border-left: 1px solid white !important;
# }
# #T_eabb7 td.col5 {
#   border-left: 1px solid white !important;
# }
# #T_eabb7 th.col9 {
#   border-left: 1px solid white !important;
# }
# #T_eabb7 td.col9 {
#   border-left: 1px solid white !important;
# }
# #T_eabb7 th.col13 {
#   border-left: 1px solid white !important;
# }
# #T_eabb7 td.col13 {
#   border-left: 1px solid white !important;
# }
# #T_eabb7_row0_col0, #T_eabb7_row0_col1, #T_eabb7_row0_col2, #T_eabb7_row0_col3, #T_eabb7_row0_col7, #T_eabb7_row0_col8, #T_eabb7_row0_col9, #T_eabb7_row0_col11, #T_eabb7_row0_col12, #T_eabb7_row0_col13, #T_eabb7_row0_col15, #T_eabb7_row0_col16, #T_eabb7_row1_col0, #T_eabb7_row1_col1, #T_eabb7_row1_col2, #T_eabb7_row1_col3, #T_eabb7_row1_col4, #T_eabb7_row1_col5, #T_eabb7_row1_col7, #T_eabb7_row1_col8, #T_eabb7_row1_col9, #T_eabb7_row1_col11, #T_eabb7_row1_col12, #T_eabb7_row1_col15, #T_eabb7_row1_col16, #T_eabb7_row2_col0, #T_eabb7_row2_col1, #T_eabb7_row2_col2, #T_eabb7_row2_col3, #T_eabb7_row2_col7, #T_eabb7_row2_col8, #T_eabb7_row2_col9, #T_eabb7_row2_col11, #T_eabb7_row2_col12, #T_eabb7_row2_col13, #T_eabb7_row2_col15, #T_eabb7_row2_col16, #T_eabb7_row3_col0, #T_eabb7_row3_col1, #T_eabb7_row3_col2, #T_eabb7_row3_col3, #T_eabb7_row3_col4, #T_eabb7_row3_col5, #T_eabb7_row3_col7, #T_eabb7_row3_col8, #T_eabb7_row3_col11, #T_eabb7_row3_col12, #T_eabb7_row3_col15, #T_eabb7_row3_col16, #T_eabb7_row4_col0, #T_eabb7_row4_col1, #T_eabb7_row4_col2, #T_eabb7_row4_col3, #T_eabb7_row4_col5, #T_eabb7_row4_col7, #T_eabb7_row4_col8, #T_eabb7_row4_col11, #T_eabb7_row4_col12, #T_eabb7_row4_col15, #T_eabb7_row4_col16, #T_eabb7_row5_col0, #T_eabb7_row5_col1, #T_eabb7_row5_col2, #T_eabb7_row5_col3, #T_eabb7_row5_col5, #T_eabb7_row5_col7, #T_eabb7_row5_col8, #T_eabb7_row5_col11, #T_eabb7_row5_col12, #T_eabb7_row5_col15, #T_eabb7_row5_col16, #T_eabb7_row6_col0, #T_eabb7_row6_col1, #T_eabb7_row6_col2, #T_eabb7_row6_col3, #T_eabb7_row6_col5, #T_eabb7_row6_col7, #T_eabb7_row6_col8, #T_eabb7_row6_col11, #T_eabb7_row6_col12, #T_eabb7_row6_col15, #T_eabb7_row6_col16, #T_eabb7_row7_col0, #T_eabb7_row7_col1, #T_eabb7_row7_col2, #T_eabb7_row7_col3, #T_eabb7_row7_col7, #T_eabb7_row7_col8, #T_eabb7_row7_col9, #T_eabb7_row7_col11, #T_eabb7_row7_col12, #T_eabb7_row7_col13, #T_eabb7_row7_col15, #T_eabb7_row7_col16, #T_eabb7_row8_col0, #T_eabb7_row8_col1, #T_eabb7_row8_col2, #T_eabb7_row8_col3, #T_eabb7_row8_col4, #T_eabb7_row8_col5, #T_eabb7_row8_col7, #T_eabb7_row8_col8, #T_eabb7_row8_col11, #T_eabb7_row8_col12, #T_eabb7_row8_col15, #T_eabb7_row8_col16, #T_eabb7_row9_col0, #T_eabb7_row9_col1, #T_eabb7_row9_col2, #T_eabb7_row9_col3, #T_eabb7_row9_col7, #T_eabb7_row9_col8, #T_eabb7_row9_col11, #T_eabb7_row9_col12, #T_eabb7_row9_col15, #T_eabb7_row9_col16, #T_eabb7_row10_col0, #T_eabb7_row10_col1, #T_eabb7_row10_col2, #T_eabb7_row10_col3, #T_eabb7_row10_col5, #T_eabb7_row10_col7, #T_eabb7_row10_col8, #T_eabb7_row10_col9, #T_eabb7_row10_col11, #T_eabb7_row10_col12, #T_eabb7_row10_col15, #T_eabb7_row10_col16, #T_eabb7_row11_col0, #T_eabb7_row11_col7, #T_eabb7_row11_col8, #T_eabb7_row11_col11, #T_eabb7_row11_col12, #T_eabb7_row11_col15, #T_eabb7_row11_col16, #T_eabb7_row12_col0, #T_eabb7_row12_col1, #T_eabb7_row12_col2, #T_eabb7_row12_col5, #T_eabb7_row12_col7, #T_eabb7_row12_col8, #T_eabb7_row12_col11, #T_eabb7_row12_col12, #T_eabb7_row12_col15, #T_eabb7_row12_col16, #T_eabb7_row13_col0, #T_eabb7_row13_col1, #T_eabb7_row13_col2, #T_eabb7_row13_col3, #T_eabb7_row13_col7, #T_eabb7_row13_col8, #T_eabb7_row13_col9, #T_eabb7_row13_col11, #T_eabb7_row13_col12, #T_eabb7_row13_col13, #T_eabb7_row13_col15, #T_eabb7_row13_col16, #T_eabb7_row14_col0, #T_eabb7_row14_col1, #T_eabb7_row14_col2, #T_eabb7_row14_col3, #T_eabb7_row14_col5, #T_eabb7_row14_col7, #T_eabb7_row14_col8, #T_eabb7_row14_col11, #T_eabb7_row14_col12, #T_eabb7_row14_col15, #T_eabb7_row14_col16, #T_eabb7_row15_col0, #T_eabb7_row15_col1, #T_eabb7_row15_col2, #T_eabb7_row15_col3, #T_eabb7_row15_col5, #T_eabb7_row15_col7, #T_eabb7_row15_col8, #T_eabb7_row15_col11, #T_eabb7_row15_col12, #T_eabb7_row15_col15, #T_eabb7_row15_col16, #T_eabb7_row16_col0, #T_eabb7_row16_col1, #T_eabb7_row16_col2, #T_eabb7_row16_col3, #T_eabb7_row16_col7, #T_eabb7_row16_col8, #T_eabb7_row16_col11, #T_eabb7_row16_col12, #T_eabb7_row16_col15, #T_eabb7_row16_col16, #T_eabb7_row17_col0, #T_eabb7_row17_col1, #T_eabb7_row17_col2, #T_eabb7_row ...
#   width: 8ch;
#   text-align: center;
# }
# #T_eabb7_row0_col4, #T_eabb7_row0_col5, #T_eabb7_row0_col6, #T_eabb7_row0_col10, #T_eabb7_row0_col14, #T_eabb7_row1_col6, #T_eabb7_row1_col10, #T_eabb7_row1_col13, #T_eabb7_row1_col14, #T_eabb7_row2_col4, #T_eabb7_row2_col5, #T_eabb7_row2_col6, #T_eabb7_row2_col10, #T_eabb7_row2_col14, #T_eabb7_row3_col6, #T_eabb7_row3_col9, #T_eabb7_row3_col10, #T_eabb7_row3_col13, #T_eabb7_row3_col14, #T_eabb7_row4_col4, #T_eabb7_row4_col6, #T_eabb7_row4_col9, #T_eabb7_row4_col10, #T_eabb7_row4_col13, #T_eabb7_row4_col14, #T_eabb7_row5_col4, #T_eabb7_row5_col6, #T_eabb7_row5_col9, #T_eabb7_row5_col10, #T_eabb7_row5_col13, #T_eabb7_row5_col14, #T_eabb7_row6_col4, #T_eabb7_row6_col6, #T_eabb7_row6_col9, #T_eabb7_row6_col10, #T_eabb7_row6_col13, #T_eabb7_row6_col14, #T_eabb7_row7_col4, #T_eabb7_row7_col5, #T_eabb7_row7_col6, #T_eabb7_row7_col10, #T_eabb7_row7_col14, #T_eabb7_row8_col6, #T_eabb7_row8_col9, #T_eabb7_row8_col10, #T_eabb7_row8_col13, #T_eabb7_row8_col14, #T_eabb7_row9_col4, #T_eabb7_row9_col5, #T_eabb7_row9_col6, #T_eabb7_row9_col9, #T_eabb7_row9_col10, #T_eabb7_row9_col13, #T_eabb7_row9_col14, #T_eabb7_row10_col4, #T_eabb7_row10_col6, #T_eabb7_row10_col10, #T_eabb7_row10_col13, #T_eabb7_row10_col14, #T_eabb7_row11_col1, #T_eabb7_row11_col2, #T_eabb7_row11_col3, #T_eabb7_row11_col4, #T_eabb7_row11_col5, #T_eabb7_row11_col6, #T_eabb7_row11_col9, #T_eabb7_row11_col10, #T_eabb7_row11_col13, #T_eabb7_row11_col14, #T_eabb7_row12_col3, #T_eabb7_row12_col4, #T_eabb7_row12_col6, #T_eabb7_row12_col9, #T_eabb7_row12_col10, #T_eabb7_row12_col13, #T_eabb7_row12_col14, #T_eabb7_row13_col4, #T_eabb7_row13_col5, #T_eabb7_row13_col6, #T_eabb7_row13_col10, #T_eabb7_row13_col14, #T_eabb7_row14_col4, #T_eabb7_row14_col6, #T_eabb7_row14_col9, #T_eabb7_row14_col10, #T_eabb7_row14_col13, #T_eabb7_row14_col14, #T_eabb7_row15_col4, #T_eabb7_row15_col6, #T_eabb7_row15_col9, #T_eabb7_row15_col10, #T_eabb7_row15_col13, #T_eabb7_row15_col14, #T_eabb7_row16_col4, #T_eabb7_row16_col5, #T_eabb7_row16_col6, #T_eabb7_row16_col9,

# %%
# funcs = ['full_reduce_flow_b', 'full_reduce_min_flow_b', 'basic_optimize', 'clifford_simp_b', 'clifford_simp_flow_b', 'clifford_simp_min_flow_b', 'full_reduce_b']
# t_probs = [0.015*i for i in range(11)]
# fig = b.Pt_graphs(funcs=funcs, qubits=8, depth=800, cnot_prob=0.3, t_probs=t_probs, ys=['Gates','2Q Count','T Count'], reps=20, overwrite=False, random_seed=42)

# %%
b.save(dirpath='benchmark_gen')
